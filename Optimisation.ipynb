# %% [markdown]
# ```python
# %display latex
# ```
#
#
# ```python
# var("a")
# f(x) = a * (1 - x^2)
# ```
#
#
# ```python
# V = pi * integrate(f^2, x, -1, 1)
# ```
#
#
# ```python
# df = diff(f, x)
# ```
#
#
# ```python
# df
# ```
#
#
#
#
# <html>\(\displaystyle x \ {\mapsto}\ -2 \, a x\)</html>

# %% [markdown]
# ```python
# S = 2 * pi * integrate(f * sqrt(1 + df^2), x, -1, 1)
# ```
#
#
# ```python
# V
# ```
#
#
#
#
# <html>\(\displaystyle \frac{16}{15} \, \pi a^{2}\)</html>
#
#
#
#
# ```python
# S
# ```
#
#
#
#
# <html>\(\displaystyle \frac{1}{16} \, \pi a {\left(16 \, \sqrt{4 \, a^{2} + 1} + \frac{16 \, \sqrt{a^{2}} \operatorname{arsinh}\left(2 \, \sqrt{a^{2}}\right)}{a^{2}} - \frac{2 \, \sqrt{4 \, a^{2} + 1}}{a^{2}} + \frac{\sqrt{a^{2}} \operatorname{arsinh}\left(2 \, \sqrt{a^{2}}\right)}{a^{4}}\right)}\)</html>
#
#
#
#
# ```python
# max_S = 15
# best_a = find_root(S==max_S, 0.1, 5)
# ```
#
#
# ```python
# S
# ```
#
#
#
#
# <html>\(\displaystyle \frac{1}{16} \, \pi a {\left(16 \, \sqrt{4 \, a^{2} + 1} + \frac{16 \, \sqrt{a^{2}} \operatorname{arsinh}\left(2 \, \sqrt{a^{2}}\right)}{a^{2}} - \frac{2 \, \sqrt{4 \, a^{2} + 1}}{a^{2}} + \frac{\sqrt{a^{2}} \operatorname{arsinh}\left(2 \, \sqrt{a^{2}}\right)}{a^{4}}\right)}\)</html>
#
#
#
#
# ```python
# best_a
# ```
#
#
#
#
# <html>\(\displaystyle 1.2438695767706438\)</html>
#
#
#
#
# ```python
# V_max = V.subs(a=best_a)
# ```
#
#
# ```python
# V_max
# ```
#
#
#
#
# <html>\(\displaystyle 1.6503589589499525 \, \pi\)</html>

# %% [markdown]
# ```python
# V_max=float(5.1847558119)
# best_a=float(1.243869577)
# limit_S=int(15)
# final_S=int(15)
#
# print("-" * 40)
# print("ЗВІТ З ОПТИМІЗАЦІЇ ГЕОМЕТРИЧНОЇ ФОРМИ")
# print("-" * 40)
#
# print(f"{'Параметр кривої (a)':<25}: {best_a:.4f}")
# print(f"{'Максимальний об''єм (V)':<25}: {V_max:.4f} куб. од.")
# print(f"{'Функція твірної':<25}: f(x) = {best_a:.4f} * (1 - x^2)")
#
#
# print("-" * 40)
# print("АНАЛІЗ ВИКОРИСТАННЯ РЕСУРСІВ:")
#
#
# usage_percent = (final_S / limit_S) * 100
# print(f"Використана площа поверхні : {final_S:.2f} / {limit_S} кв. од.")
# print(f"Відсоток використання площі : {usage_percent:.1f}%")
# print("-" * 40)
# ```
#
#     ----------------------------------------
#     ЗВІТ З ОПТИМІЗАЦІЇ ГЕОМЕТРИЧНОЇ ФОРМИ
#     ----------------------------------------
#     Параметр кривої (a)      : 1.2439
#     Максимальний обєм (V)    : 5.1848 куб. од.
#     Функція твірної          : f(x) = 1.2439 * (1 - x^2)
#     ----------------------------------------
#     АНАЛІЗ ВИКОРИСТАННЯ РЕСУРСІВ:
#     Використана площа поверхні : 15.00 / 15 кв. од.
#     Відсоток використання площі : 100.0%
#     ----------------------------------------
