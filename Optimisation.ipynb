# %% [markdown]
# ```python
# %display latex
# ```
#
#
# ```python
# var("a")
# f(x) = a * (1 - x^2)
# ```
#
#
# ```python
# V = pi * integrate(f^2, x, -1, 1)
# ```
#
#
# ```python
# df = diff(f, x)
# ```
#
#
# ```python
# df
# ```
#
#
#
#
# <html>\(\displaystyle x \ {\mapsto}\ -2 \, a x\)</html>
